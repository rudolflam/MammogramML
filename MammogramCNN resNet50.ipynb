# %%
import dicom
import pylab
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img, img_to_array
import scipy.misc
from scipy.misc import imsave
import numpy as np

from keras.applications import vgg16,resnet50
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Reshape, Dropout
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Convolution2D, MaxPooling2D, Conv2D
from keras.layers.core import Flatten
from keras.optimizers import SGD
from keras.layers import Input, Dense
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
import os

# %%
img = load_img(path='./png_images/000138.dcm.png', grayscale=True)

plt.imshow(img)
plt.show()

# %%
img = img_to_array(img)
img = np.dstack([img[:,:,0],img[:,:,0],img[:,:,0]])

# %%
def preprocess_image(img):
    img = img_to_array(img)
    img = np.dstack([img[:,:,0],img[:,:,0],img[:,:,0]])
    img = np.expand_dims(img, axis=0)
    return img

# %%
ppimg = preprocess_image(img)

# %%
ppimg.shape
# Out:
# (1, 250, 250, 3)

# %%
ylabels = ["cancerL","cancerR","invL","invR","age","implantEver","implantNow","bcHistory","yearsSincePreviousBc","previousBcLaterality","reduxHistory","reduxLaterality","hrt","antiestrogen","firstDegreeWithBc","firstDegreeWithBc50","bmi","race"
]

# %%
# read data files
import csv

# %%
outcomes = {}
with open('data/exams_metadata_pilot_20160906.tsv') as csvfile:
    reader = csv.reader(csvfile, delimiter='\t')
    def try_int(e):
        try:
            return int(e)
        except:
            return 0.5
    def onehot(n, e=0):
        v = np.zeros((1,n))
        v[0,e] = 1
        return v
    
    next(reader)
    for row in reader:
            eid = tuple([int(x) for x in row[:2]])
            cancer = np.array([float(try_int(x)) for x in row[3:7]]).reshape(1,4)
            age = np.array([int(row[6])])
            redux = np.array([float(try_int(x)) for x in row[13:14]])
            redux_lat = np.array([float(try_int(x)) for x in row[14:15]])
            try:
                i = int(row[14])
                redux_lat = onehot(2,i-1)
            except ValueError:
                redux_lat = np.zeros((1,2))
            except IndexError:
                redux_lat = np.ones((1,2))
            
            treatment = np.array([float(x) if float(x)<=1 else 0.5 for x in row[15:17]]).reshape(1,2)
            race = onehot(9, int(row[-1])-1 )

            outcomes[eid] = {'cancer': cancer,
                             #'age':age,
                             'reductions': redux,
                             'reduction_laterality': redux_lat,
                             'treatments':treatment,
                             'race':race}

# %%
name='drop1NONEresnet'

# %%
with tf.device('/gpu:0'):
    resnet_model = resnet50.ResNet50(include_top=False, weights='imagenet', input_shape=(250,250,3), pooling='avg')
    #vgg16_model = vgg16.VGG16(include_top=False,weights='imagenet', input_shape=(250,250,3))
    #for i,layer in enumerate(vgg16_model.layers):
    #    print(i, layer.output_shape, layer.name)
    for layer in resnet_model.layers:
        layer.trainable = False
        
    #Adding specialized layers 
    x = resnet_model.output
    #x = Flatten()(x)
    x = Dense(1024, activation="relu")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation="relu")(x)
    
    #Adding different output layers
    #age_prediction = Dense(1,name='age)(x)
    reduction_prediction = Dense(1, activation="sigmoid",name='reduction')(x)
    reduction_lat_prediction = Dense(2, activation="softmax", name='reduction_lat')(x)
    treatment_prediction = Dense(2, activation="sigmoid", name='treatment')(x)
    race_prediction = Dense(9, activation='softmax',name='race')(x)
    cancer_prediction = Dense(4, activation="sigmoid",name='cancer')(x)
    
    # creating the entire model 
    model = Model(input = resnet_model.input, output = [#age_prediction, 
                                                      reduction_prediction, 
                                                      reduction_lat_prediction,
                                                      treatment_prediction,
                                                      race_prediction,
                                                      cancer_prediction])
    # compile the model 
    model.compile(optimizer=SGD(lr=0.0001, momentum=0.9),
                  loss=[#'mean_squared_error',
                        'binary_crossentropy',
                        'categorical_crossentropy',
                        'binary_crossentropy',
                        'categorical_crossentropy',
                        'binary_crossentropy'],
                  loss_weights=[0.125,0.125,0.125,0.125,0.5],
                  metrics=['accuracy'])
    
    model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 250, 250, 3)   0
# ____________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D) (None, 256, 256, 3)   0           input_1[0][0]
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 125, 125, 64)  9472        zero_padding2d_1[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 125, 125, 64)  256         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 125, 125, 64)  0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 62, 62, 64)    0           activation_1[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2a (Conv2D)          (None, 62, 62, 64)    4160        max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizatio (None, 62, 62, 64)    256         res2a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 62, 62, 64)    0           bn2a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2b (Conv2D)          (None, 62, 62, 64)    36928       activation_2[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizatio (None, 62, 62, 64)    256         res2a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 62, 62, 64)    0           bn2a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2a_branch2c (Conv2D)          (None, 62, 62, 256)   16640       activation_3[0][0]
# ____________________________________________________________________________________________________
# res2a_branch1 (Conv2D)           (None, 62, 62, 256)   16640       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizatio (None, 62, 62, 256)   1024        res2a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalization (None, 62, 62, 256)   1024        res2a_branch1[0][0]
# ____________________________________________________________________________________________________
# add_1 (Add)                      (None, 62, 62, 256)   0           bn2a_branch2c[0][0]
#                                                                    bn2a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 62, 62, 256)   0           add_1[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2a (Conv2D)          (None, 62, 62, 64)    16448       activation_4[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizatio (None, 62, 62, 64)    256         res2b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 62, 62, 64)    0           bn2b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2b (Conv2D)          (None, 62, 62, 64)    36928       activation_5[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizatio (None, 62, 62, 64)    256         res2b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 62, 62, 64)    0           bn2b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2b_branch2c (Conv2D)          (None, 62, 62, 256)   16640       activation_6[0][0]
# ____________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizatio (None, 62, 62, 256)   1024        res2b_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_2 (Add)                      (None, 62, 62, 256)   0           bn2b_branch2c[0][0]
#                                                                    activation_4[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 62, 62, 256)   0           add_2[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2a (Conv2D)          (None, 62, 62, 64)    16448       activation_7[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizatio (None, 62, 62, 64)    256         res2c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 62, 62, 64)    0           bn2c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2b (Conv2D)          (None, 62, 62, 64)    36928       activation_8[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizatio (None, 62, 62, 64)    256         res2c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 62, 62, 64)    0           bn2c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res2c_branch2c (Conv2D)          (None, 62, 62, 256)   16640       activation_9[0][0]
# ____________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizatio (None, 62, 62, 256)   1024        res2c_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_3 (Add)                      (None, 62, 62, 256)   0           bn2c_branch2c[0][0]
#                                                                    activation_7[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 62, 62, 256)   0           add_3[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2a (Conv2D)          (None, 31, 31, 128)   32896       activation_10[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizatio (None, 31, 31, 128)   512         res3a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 31, 31, 128)   0           bn3a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2b (Conv2D)          (None, 31, 31, 128)   147584      activation_11[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizatio (None, 31, 31, 128)   512         res3a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 31, 31, 128)   0           bn3a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3a_branch2c (Conv2D)          (None, 31, 31, 512)   66048       activation_12[0][0]
# ____________________________________________________________________________________________________
# res3a_branch1 (Conv2D)           (None, 31, 31, 512)   131584      activation_10[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizatio (None, 31, 31, 512)   2048        res3a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalization (None, 31, 31, 512)   2048        res3a_branch1[0][0]
# ____________________________________________________________________________________________________
# add_4 (Add)                      (None, 31, 31, 512)   0           bn3a_branch2c[0][0]
#                                                                    bn3a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 31, 31, 512)   0           add_4[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2a (Conv2D)          (None, 31, 31, 128)   65664       activation_13[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizatio (None, 31, 31, 128)   512         res3b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 31, 31, 128)   0           bn3b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2b (Conv2D)          (None, 31, 31, 128)   147584      activation_14[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizatio (None, 31, 31, 128)   512         res3b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 31, 31, 128)   0           bn3b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3b_branch2c (Conv2D)          (None, 31, 31, 512)   66048       activation_15[0][0]
# ____________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizatio (None, 31, 31, 512)   2048        res3b_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_5 (Add)                      (None, 31, 31, 512)   0           bn3b_branch2c[0][0]
#                                                                    activation_13[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 31, 31, 512)   0           add_5[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2a (Conv2D)          (None, 31, 31, 128)   65664       activation_16[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizatio (None, 31, 31, 128)   512         res3c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 31, 31, 128)   0           bn3c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2b (Conv2D)          (None, 31, 31, 128)   147584      activation_17[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizatio (None, 31, 31, 128)   512         res3c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, 31, 31, 128)   0           bn3c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3c_branch2c (Conv2D)          (None, 31, 31, 512)   66048       activation_18[0][0]
# ____________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizatio (None, 31, 31, 512)   2048        res3c_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_6 (Add)                      (None, 31, 31, 512)   0           bn3c_branch2c[0][0]
#                                                                    activation_16[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 31, 31, 512)   0           add_6[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2a (Conv2D)          (None, 31, 31, 128)   65664       activation_19[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizatio (None, 31, 31, 128)   512         res3d_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 31, 31, 128)   0           bn3d_branch2a[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2b (Conv2D)          (None, 31, 31, 128)   147584      activation_20[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizatio (None, 31, 31, 128)   512         res3d_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 31, 31, 128)   0           bn3d_branch2b[0][0]
# ____________________________________________________________________________________________________
# res3d_branch2c (Conv2D)          (None, 31, 31, 512)   66048       activation_21[0][0]
# ____________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizatio (None, 31, 31, 512)   2048        res3d_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_7 (Add)                      (None, 31, 31, 512)   0           bn3d_branch2c[0][0]
#                                                                    activation_19[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 31, 31, 512)   0           add_7[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2a (Conv2D)          (None, 16, 16, 256)   131328      activation_22[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizatio (None, 16, 16, 256)   1024        res4a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, 16, 16, 256)   0           bn4a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2b (Conv2D)          (None, 16, 16, 256)   590080      activation_23[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizatio (None, 16, 16, 256)   1024        res4a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_24 (Activation)       (None, 16, 16, 256)   0           bn4a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4a_branch2c (Conv2D)          (None, 16, 16, 1024)  263168      activation_24[0][0]
# ____________________________________________________________________________________________________
# res4a_branch1 (Conv2D)           (None, 16, 16, 1024)  525312      activation_22[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizatio (None, 16, 16, 1024)  4096        res4a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalization (None, 16, 16, 1024)  4096        res4a_branch1[0][0]
# ____________________________________________________________________________________________________
# add_8 (Add)                      (None, 16, 16, 1024)  0           bn4a_branch2c[0][0]
#                                                                    bn4a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_25 (Activation)       (None, 16, 16, 1024)  0           add_8[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2a (Conv2D)          (None, 16, 16, 256)   262400      activation_25[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizatio (None, 16, 16, 256)   1024        res4b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_26 (Activation)       (None, 16, 16, 256)   0           bn4b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2b (Conv2D)          (None, 16, 16, 256)   590080      activation_26[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizatio (None, 16, 16, 256)   1024        res4b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_27 (Activation)       (None, 16, 16, 256)   0           bn4b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4b_branch2c (Conv2D)          (None, 16, 16, 1024)  263168      activation_27[0][0]
# ____________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizatio (None, 16, 16, 1024)  4096        res4b_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_9 (Add)                      (None, 16, 16, 1024)  0           bn4b_branch2c[0][0]
#                                                                    activation_25[0][0]
# ____________________________________________________________________________________________________
# activation_28 (Activation)       (None, 16, 16, 1024)  0           add_9[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2a (Conv2D)          (None, 16, 16, 256)   262400      activation_28[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizatio (None, 16, 16, 256)   1024        res4c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_29 (Activation)       (None, 16, 16, 256)   0           bn4c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2b (Conv2D)          (None, 16, 16, 256)   590080      activation_29[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizatio (None, 16, 16, 256)   1024        res4c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_30 (Activation)       (None, 16, 16, 256)   0           bn4c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4c_branch2c (Conv2D)          (None, 16, 16, 1024)  263168      activation_30[0][0]
# ____________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizatio (None, 16, 16, 1024)  4096        res4c_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_10 (Add)                     (None, 16, 16, 1024)  0           bn4c_branch2c[0][0]
#                                                                    activation_28[0][0]
# ____________________________________________________________________________________________________
# activation_31 (Activation)       (None, 16, 16, 1024)  0           add_10[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2a (Conv2D)          (None, 16, 16, 256)   262400      activation_31[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizatio (None, 16, 16, 256)   1024        res4d_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_32 (Activation)       (None, 16, 16, 256)   0           bn4d_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2b (Conv2D)          (None, 16, 16, 256)   590080      activation_32[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizatio (None, 16, 16, 256)   1024        res4d_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_33 (Activation)       (None, 16, 16, 256)   0           bn4d_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4d_branch2c (Conv2D)          (None, 16, 16, 1024)  263168      activation_33[0][0]
# ____________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizatio (None, 16, 16, 1024)  4096        res4d_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_11 (Add)                     (None, 16, 16, 1024)  0           bn4d_branch2c[0][0]
#                                                                    activation_31[0][0]
# ____________________________________________________________________________________________________
# activation_34 (Activation)       (None, 16, 16, 1024)  0           add_11[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2a (Conv2D)          (None, 16, 16, 256)   262400      activation_34[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizatio (None, 16, 16, 256)   1024        res4e_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_35 (Activation)       (None, 16, 16, 256)   0           bn4e_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2b (Conv2D)          (None, 16, 16, 256)   590080      activation_35[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizatio (None, 16, 16, 256)   1024        res4e_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_36 (Activation)       (None, 16, 16, 256)   0           bn4e_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4e_branch2c (Conv2D)          (None, 16, 16, 1024)  263168      activation_36[0][0]
# ____________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizatio (None, 16, 16, 1024)  4096        res4e_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_12 (Add)                     (None, 16, 16, 1024)  0           bn4e_branch2c[0][0]
#                                                                    activation_34[0][0]
# ____________________________________________________________________________________________________
# activation_37 (Activation)       (None, 16, 16, 1024)  0           add_12[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2a (Conv2D)          (None, 16, 16, 256)   262400      activation_37[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizatio (None, 16, 16, 256)   1024        res4f_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_38 (Activation)       (None, 16, 16, 256)   0           bn4f_branch2a[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2b (Conv2D)          (None, 16, 16, 256)   590080      activation_38[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizatio (None, 16, 16, 256)   1024        res4f_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_39 (Activation)       (None, 16, 16, 256)   0           bn4f_branch2b[0][0]
# ____________________________________________________________________________________________________
# res4f_branch2c (Conv2D)          (None, 16, 16, 1024)  263168      activation_39[0][0]
# ____________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizatio (None, 16, 16, 1024)  4096        res4f_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_13 (Add)                     (None, 16, 16, 1024)  0           bn4f_branch2c[0][0]
#                                                                    activation_37[0][0]
# ____________________________________________________________________________________________________
# activation_40 (Activation)       (None, 16, 16, 1024)  0           add_13[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2a (Conv2D)          (None, 8, 8, 512)     524800      activation_40[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizatio (None, 8, 8, 512)     2048        res5a_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_41 (Activation)       (None, 8, 8, 512)     0           bn5a_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2b (Conv2D)          (None, 8, 8, 512)     2359808     activation_41[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizatio (None, 8, 8, 512)     2048        res5a_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_42 (Activation)       (None, 8, 8, 512)     0           bn5a_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5a_branch2c (Conv2D)          (None, 8, 8, 2048)    1050624     activation_42[0][0]
# ____________________________________________________________________________________________________
# res5a_branch1 (Conv2D)           (None, 8, 8, 2048)    2099200     activation_40[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizatio (None, 8, 8, 2048)    8192        res5a_branch2c[0][0]
# ____________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalization (None, 8, 8, 2048)    8192        res5a_branch1[0][0]
# ____________________________________________________________________________________________________
# add_14 (Add)                     (None, 8, 8, 2048)    0           bn5a_branch2c[0][0]
#                                                                    bn5a_branch1[0][0]
# ____________________________________________________________________________________________________
# activation_43 (Activation)       (None, 8, 8, 2048)    0           add_14[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2a (Conv2D)          (None, 8, 8, 512)     1049088     activation_43[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizatio (None, 8, 8, 512)     2048        res5b_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_44 (Activation)       (None, 8, 8, 512)     0           bn5b_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2b (Conv2D)          (None, 8, 8, 512)     2359808     activation_44[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizatio (None, 8, 8, 512)     2048        res5b_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_45 (Activation)       (None, 8, 8, 512)     0           bn5b_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5b_branch2c (Conv2D)          (None, 8, 8, 2048)    1050624     activation_45[0][0]
# ____________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizatio (None, 8, 8, 2048)    8192        res5b_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_15 (Add)                     (None, 8, 8, 2048)    0           bn5b_branch2c[0][0]
#                                                                    activation_43[0][0]
# ____________________________________________________________________________________________________
# activation_46 (Activation)       (None, 8, 8, 2048)    0           add_15[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2a (Conv2D)          (None, 8, 8, 512)     1049088     activation_46[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizatio (None, 8, 8, 512)     2048        res5c_branch2a[0][0]
# ____________________________________________________________________________________________________
# activation_47 (Activation)       (None, 8, 8, 512)     0           bn5c_branch2a[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2b (Conv2D)          (None, 8, 8, 512)     2359808     activation_47[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizatio (None, 8, 8, 512)     2048        res5c_branch2b[0][0]
# ____________________________________________________________________________________________________
# activation_48 (Activation)       (None, 8, 8, 512)     0           bn5c_branch2b[0][0]
# ____________________________________________________________________________________________________
# res5c_branch2c (Conv2D)          (None, 8, 8, 2048)    1050624     activation_48[0][0]
# ____________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizatio (None, 8, 8, 2048)    8192        res5c_branch2c[0][0]
# ____________________________________________________________________________________________________
# add_16 (Add)                     (None, 8, 8, 2048)    0           bn5c_branch2c[0][0]
#                                                                    activation_46[0][0]
# ____________________________________________________________________________________________________
# activation_49 (Activation)       (None, 8, 8, 2048)    0           add_16[0][0]
# ____________________________________________________________________________________________________
# avg_pool (AveragePooling2D)      (None, 1, 1, 2048)    0           activation_49[0][0]
# ____________________________________________________________________________________________________
# global_average_pooling2d_1 (Glob (None, 2048)          0           avg_pool[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1024)          2098176     global_average_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 1024)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 256)           262400      dropout_1[0][0]
# ____________________________________________________________________________________________________
# reduction (Dense)                (None, 1)             257         dense_2[0][0]
# ____________________________________________________________________________________________________
# reduction_lat (Dense)            (None, 2)             514         dense_2[0][0]
# ____________________________________________________________________________________________________
# treatment (Dense)                (None, 2)             514         dense_2[0][0]
# ____________________________________________________________________________________________________
# race (Dense)                     (None, 9)             2313        dense_2[0][0]
# ____________________________________________________________________________________________________
# cancer (Dense)                   (None, 4)             1028        dense_2[0][0]
# ====================================================================================================
# Total params: 25,952,914
# Trainable params: 2,365,202
# Non-trainable params: 23,587,712
# ____________________________________________________________________________________________________
# /home/rudolf/.local/lib/python3.5/site-packages/ipykernel/__main__.py:30: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=[<tf.Tenso...)`

# %%
def generator(verbose=False, filepath='data/training.tsv'):
    if verbose:
        from IPython.display import clear_output
    with open(filepath) as csvfile:
        reader = csv.reader(csvfile, delimiter='\t')
        next(reader)
        lines = list(reader)
        n = len(lines)
        i = -1
        while True:
            i = i+1
            row = lines[i%n]
            subjectId,examIndex,imageIndex,*_,filename,cancer = row
            img = load_img(path='./png_images/%s.png'%(filename), grayscale=True)
            if verbose:
                clear_output()
                print('Processing')
                plt.imshow(img)
                plt.show()
            img = preprocess_image(img)
            eid = tuple([int(x) for x in row[:2]])
            y = outcomes[eid]
            yield img,[ #y['age'],
                        y['reductions'],
                        y['reduction_laterality'],
                        y['treatments'],
                        y['race'], 
                        y['cancer']]

# %%
from keras.callbacks import Callback
class TestCallback(Callback):
    def __init__(self):
        self.generator = generator(filepath='data/test.tsv')
        self.logs = {}
        self.evaluations = {}
    def on_epoch_end(self, epoch, logs={}):
        evals = self.model.evaluate_generator(self.generator,32)
        self.logs[epoch] = logs
        self.evaluations[epoch] = evals
        #print('\nEpoch: {} Testing loss: {}, acc: {}\n'.format(epoch, losses, acc))

# %%
cb = TestCallback()
model.fit_generator(generator(),
                    samples_per_epoch=4, 
                    nb_epoch=400,
                    verbose=1,
                    callbacks=[cb])
# Out:
# /home/rudolf/.local/lib/python3.5/site-packages/ipykernel/__main__.py:6: UserWarning: The semantics of the Keras 2 argument  `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Update your method calls accordingly.
# /home/rudolf/.local/lib/python3.5/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., verbose=1, steps_per_epoch=4, callbacks=[<__main__..., epochs=400)`
# Epoch 1/400
# 4/4 [==============================] - 3s - loss: 0.8679 - reduction_loss: 0.7444 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.7629 - race_loss: 1.6676 - cancer_loss: 0.9420 - reduction_acc: 0.0000e+00 - reduction_lat_acc: 1.0000 - treatment_acc: 0.5000 - race_acc: 0.7500 - cancer_acc: 0.3125
# Epoch 2/400
# 4/4 [==============================] - 2s - loss: 0.8123 - reduction_loss: 0.5879 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.6983 - race_loss: 2.0203 - cancer_loss: 0.7979 - reduction_acc: 0.7500 - reduction_lat_acc: 0.7500 - treatment_acc: 0.5000 - race_acc: 0.0000e+00 - cancer_acc: 0.3125
# Epoch 3/400
# 4/4 [==============================] - 2s - loss: 0.7665 - reduction_loss: 0.7173 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.7126 - race_loss: 1.3996 - cancer_loss: 0.8257 - reduction_acc: 0.0000e+00 - reduction_lat_acc: 0.5000 - treatment_acc: 0.0000e+00 - race_acc: 0.7500 - cancer_acc: 0.2500
# Epoch 4/400
# 4/4 [==============================] - 1s - loss: 0.7048 - reduction_loss: 0.7147 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.6442 - race_loss: 1.2578 - cancer_loss: 0.7554 - reduction_acc: 0.2500 - reduction_lat_acc: 0.5000 - treatment_acc: 0.5000 - race_acc: 1.0000 - cancer_acc: 0.5625
# Epoch 5/400
# 4/4 [==============================] - 1s - loss: 0.7669 - reduction_loss: 0.6483 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.7628 - race_loss: 1.5155 - cancer_loss: 0.8021 - reduction_acc: 0.5000 - reduction_lat_acc: 0.7500 - treatment_acc: 0.5000 - race_acc: 0.7500 - cancer_acc: 0.3125
# Epoch 6/400
# 4/4 [==============================] - 1s - loss: 0.6890 - reduction_loss: 0.5083 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.7143 - race_loss: 1.5258 - cancer_loss: 0.6909 - reduction_acc: 0.7500 - reduction_lat_acc: 1.0000 - treatment_acc: 0.5000 - race_acc: 0.2500 - cancer_acc: 0.5000
# Epoch 7/400
# 4/4 [==============================] - 1s - loss: 0.6580 - reduction_loss: 0.5689 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.5779 - race_loss: 1.3435 - cancer_loss: 0.6934 - reduction_acc: 1.0000 - reduction_lat_acc: 0.7500 - treatment_acc: 0.7500 - race_acc: 1.0000 - cancer_acc: 0.6250
# Epoch 8/400
# 4/4 [==============================] - 1s - loss: 0.5757 - reduction_loss: 0.5568 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.5249 - race_loss: 1.1443 - cancer_loss: 0.5948 - reduction_acc: 0.7500 - reduction_lat_acc: 1.0000 - treatment_acc: 0.8750 - race_acc: 1.0000 - cancer_acc: 0.7500
# Epoch 9/400
# 4/4 [==============================] - 1s - loss: 0.6345 - reduction_loss: 0.5532 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.6221 - race_loss: 1.2597 - cancer_loss: 0.6603 - reduction_acc: 1.0000 - reduction_lat_acc: 0.2500 - treatment_acc: 0.8750 - race_acc: 1.0000 - cancer_acc: 0.6875
# Epoch 10/400
# 4/4 [==============================] - 1s - loss: 0.5974 - reduction_loss: 0.7062 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.6536 - race_loss: 1.1378 - cancer_loss: 0.5703 - reduction_acc: 0.2500 - reduction_lat_acc: 0.5000 - treatment_acc: 0.6250 - race_acc: 1.0000 - cancer_acc: 0.7500
# Epoch 11/400
# 4/4 [==============================] - 1s - loss: 0.6658 - reduction_loss: 0.5012 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.5647 - race_loss: 1.0011 - cancer_loss: 0.8148 - reduction_acc: 0.7500 - reduction_lat_acc: 0.5000 - treatment_acc: 0.8750 - race_acc: 1.0000 - cancer_acc: 0.5000
# Epoch 12/400
# 4/4 [==============================] - 1s - loss: 0.6233 - reduction_loss: 0.5971 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.5233 - race_loss: 1.1561 - cancer_loss: 0.6774 - reduction_acc: 0.7500 - reduction_lat_acc: 1.0000 - treatment_acc: 1.0000 - race_acc: 1.0000 - cancer_acc: 0.5625
# Epoch 13/400
# 4/4 [==============================] - 1s - loss: 0.5318 - reduction_loss: 0.3274 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.6415 - race_loss: 0.8261 - cancer_loss: 0.6149 - reduction_acc: 1.0000 - reduction_lat_acc: 1.0000 - treatment_acc: 0.7500 - race_acc: 1.0000 - cancer_acc: 0.6250
# Epoch 14/400
# 4/4 [==============================] - 1s - loss: 0.5649 - reduction_loss: 0.4422 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.4984 - race_loss: 1.0551 - cancer_loss: 0.6309 - reduction_acc: 0.7500 - reduction_lat_acc: 0.2500 - treatment_acc: 0.8750 - race_acc: 1.0000 - cancer_acc: 0.8125
# Epoch 15/400
# 4/4 [==============================] - 1s - loss: 0.5231 - reduction_loss: 0.4244 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.4700 - race_loss: 0.9536 - cancer_loss: 0.5841 - reduction_acc: 1.0000 - reduction_lat_acc: 1.0000 - treatment_acc: 1.0000 - race_acc: 1.0000 - cancer_acc: 0.7500
# Epoch 16/400
# 4/4 [==============================] - 1s - loss: 0.4959 - reduction_loss: 0.4855 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.5900 - race_loss: 0.8120 - cancer_loss: 0.5200 - reduction_acc: 1.0000 - reduction_lat_acc: 0.2500 - treatment_acc: 0.6250 - race_acc: 1.0000 - cancer_acc: 0.8750
# Epoch 17/400
# 4/4 [==============================] - 1s - loss: 0.5463 - reduction_loss: 0.4512 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.5733 - race_loss: 1.0967 - cancer_loss: 0.5623 - reduction_acc: 0.7500 - reduction_lat_acc: 0.5000 - treatment_acc: 0.7500 - race_acc: 0.7500 - cancer_acc: 0.8125
# Epoch 18/400
# 4/4 [==============================] - 1s - loss: 0.7228 - reduction_loss: 0.7457 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.6689 - race_loss: 2.0462 - cancer_loss: 0.5805 - reduction_acc: 0.0000e+00 - reduction_lat_acc: 0.7500 - treatment_acc: 0.2500 - race_acc: 0.2500 - cancer_acc: 0.6875
# Epoch 19/400
# 4/4 [==============================] - 1s - loss: 0.6435 - reduction_loss: 0.8088 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.4017 - race_loss: 0.6819 - cancer_loss: 0.8139 - reduction_acc: 0.0000e+00 - reduction_lat_acc: 1.0000 - treatment_acc: 1.0000 - race_acc: 1.0000 - cancer_acc: 0.4375
# Epoch 20/400
# 4/4 [==============================] - 1s - loss: 0.4818 - reduction_loss: 0.5102 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.4292 - race_loss: 0.7599 - cancer_loss: 0.5389 - reduction_acc: 0.7500 - reduction_lat_acc: 0.7500 - treatment_acc: 0.8750 - race_acc: 1.0000 - cancer_acc: 0.8125
# Epoch 21/400
# 4/4 [==============================] - 1s - loss: 0.4050 - reduction_loss: 0.3671 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.3811 - race_loss: 0.7349 - cancer_loss: 0.4393 - reduction_acc: 1.0000 - reduction_lat_acc: 0.7500 - treatment_acc: 1.0000 - race_acc: 1.0000 - cancer_acc: 0.9375
# Epoch 22/400
# 4/4 [==============================] - 1s - loss: 0.3950 - reduction_loss: 0.4444 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.
- reduction_acc: 0.0000e+00 - reduction_lat_acc: 0.7500 - treatment_acc: 0.0000e+00 - race_acc: 1.0000 - cancer_acc: 1.0000
# Epoch 391/400
# 4/4 [==============================] - 1s - loss: 0.3199 - reduction_loss: 1.2068 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.8597 - race_loss: 0.2081 - cancer_loss: 0.0711 - reduction_acc: 0.2500 - reduction_lat_acc: 0.7500 - treatment_acc: 0.2500 - race_acc: 1.0000 - cancer_acc: 1.0000
# Epoch 392/400
# 4/4 [==============================] - 1s - loss: 0.1178 - reduction_loss: 0.1601 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.1259 - race_loss: 0.2563 - cancer_loss: 0.1001 - reduction_acc: 1.0000 - reduction_lat_acc: 0.7500 - treatment_acc: 1.0000 - race_acc: 1.0000 - cancer_acc: 1.0000
# Epoch 393/400
# 4/4 [==============================] - 1s - loss: 0.2051 - reduction_loss: 0.1538 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.3505 - race_loss: 0.8761 - cancer_loss: 0.0650 - reduction_acc: 1.0000 - reduction_lat_acc: 0.7500 - treatment_acc: 0.7500 - race_acc: 0.7500 - cancer_acc: 1.0000
# Epoch 394/400
# 4/4 [==============================] - 1s - loss: 0.6030 - reduction_loss: 0.1472 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 1.1415 - race_loss: 3.2274 - cancer_loss: 0.0770 - reduction_acc: 1.0000 - reduction_lat_acc: 0.7500 - treatment_acc: 0.0000e+00 - race_acc: 0.0000e+00 - cancer_acc: 1.0000
# Epoch 395/400
# 4/4 [==============================] - 1s - loss: 0.7662 - reduction_loss: 0.7549 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 1.0872 - race_loss: 4.0330 - cancer_loss: 0.0637 - reduction_acc: 0.2500 - reduction_lat_acc: 0.2500 - treatment_acc: 0.0000e+00 - race_acc: 0.0000e+00 - cancer_acc: 1.0000
# Epoch 396/400
# 4/4 [==============================] - 1s - loss: 0.6812 - reduction_loss: 1.1135 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 1.0372 - race_loss: 3.0124 - cancer_loss: 0.0716 - reduction_acc: 0.0000e+00 - reduction_lat_acc: 0.0000e+00 - treatment_acc: 0.0000e+00 - race_acc: 0.0000e+00 - cancer_acc: 1.0000
# Epoch 397/400
# 4/4 [==============================] - 1s - loss: 0.3957 - reduction_loss: 0.4748 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.5996 - race_loss: 1.6869 - cancer_loss: 0.1010 - reduction_acc: 0.5000 - reduction_lat_acc: 0.7500 - treatment_acc: 0.5000 - race_acc: 0.5000 - cancer_acc: 1.0000
# Epoch 398/400
# 4/4 [==============================] - 1s - loss: 0.3505 - reduction_loss: 0.1623 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.1785 - race_loss: 2.1660 - cancer_loss: 0.0744 - reduction_acc: 1.0000 - reduction_lat_acc: 0.7500 - treatment_acc: 1.0000 - race_acc: 0.5000 - cancer_acc: 1.0000
# Epoch 399/400
# 4/4 [==============================] - 1s - loss: 0.3133 - reduction_loss: 0.0953 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.1839 - race_loss: 1.9714 - cancer_loss: 0.0639 - reduction_acc: 1.0000 - reduction_lat_acc: 1.0000 - treatment_acc: 1.0000 - race_acc: 0.5000 - cancer_acc: 1.0000
# Epoch 400/400
# 4/4 [==============================] - 1s - loss: 0.2257 - reduction_loss: 0.5958 - reduction_lat_loss: -0.0000e+00 - treatment_loss: 0.6844 - race_loss: 0.2584 - cancer_loss: 0.0667 - reduction_acc: 0.5000 - reduction_lat_acc: 0.7500 - treatment_acc: 0.5000 - race_acc: 1.0000 - cancer_acc: 1.0000

# %%
reduction_acc,reduction_loss,reduction_lat_acc,reduction_lat_loss,treatment_acc,treatment_loss,race_acc,race_loss,cancer_acc,cancer_loss,loss=[],[],[],[],[],[],[],[],[],[],[]

# %%
logs = cb.logs
epochs = []
for epoch, log in logs.items():
    epochs.append([epoch])
    reduction_acc.append(log['reduction_acc'])
    reduction_loss.append(log['reduction_loss'])
    reduction_lat_acc.append(log['reduction_lat_acc'])
    reduction_lat_loss.append(log['reduction_lat_loss'])
    treatment_acc.append(log['treatment_acc'])
    treatment_loss.append(log['treatment_loss'])
    race_acc.append(log['race_acc'])
    race_loss.append(log['race_loss'])
    cancer_acc.append(log['cancer_acc'])
    cancer_loss.append(log['cancer_loss'])
    loss.append(log['loss'])

# %%
import matplotlib.pyplot as plt
import pylab

# %%
plt.plot(epochs, reduction_acc)
plt.plot(epochs, reduction_lat_acc)
plt.plot(epochs, treatment_acc)
plt.plot(epochs, race_acc)
plt.plot(epochs, cancer_acc)
plt.legend(['reduction_acc', 'reduction_lat_acc', 'treatment_acc', 'race_acc', 'cancer_acc'],loc='center left',bbox_to_anchor=(1, 0.5))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Training accuracy over epochs')
plt.savefig('research_data/training_acc_%s.png'%name, bbox_inches = 'tight')
plt.show()

# %%
plt.plot(epochs, reduction_loss)
plt.plot(epochs, reduction_lat_loss)
plt.plot(epochs, treatment_loss)
plt.plot(epochs, race_loss)
plt.plot(epochs, cancer_loss)
plt.legend(['reduction_loss', 'reduction_lat_loss', 'treatment_loss', 'race_loss', 'cancer_loss'],loc='center left',bbox_to_anchor=(1, 0.5))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Training loss over epochs')
plt.ylim(0, 14)
plt.savefig('research_data/training_loss_%s.png'%name, bbox_inches = 'tight')
plt.show()

# %%
plt.plot(epochs, loss)
plt.xlabel('epoch')
plt.ylabel('total loss')
plt.title('Total training loss over epochs')
plt.ylim(0, 6)
plt.savefig('research_data/total_training_loss_%s.png'%name, bbox_inches = 'tight')
plt.show()

# %%
test_total_loss = [ cb.evaluations[e[0]][0] for e in epochs]


plt.plot(epochs, test_total_loss)
plt.xlabel('epoch')
plt.ylabel('test total loss')
plt.title('Total test loss over epochs')
plt.ylim(0, 6)
plt.savefig('research_data/total_test_loss_%s.png'%name, bbox_inches = 'tight')
plt.show()

# %%
reduction_acc,reduction_loss,reduction_lat_acc,reduction_lat_loss,treatment_acc,treatment_loss,race_acc,race_loss,cancer_acc,cancer_loss,loss=model.evaluate_generator(generator(filepath='data/test.tsv'),100)

# %%
reduction_acc,reduction_loss,reduction_lat_acc,reduction_lat_loss,treatment_acc,treatment_loss,race_acc,race_loss,cancer_acc,cancer_loss,loss
# Out:
# (0.35208707146346568,
#  0.48925313431769607,
#  0.0,
#  0.2838612311705947,
#  1.4729678539931774,
#  0.14265359148383142,
#  0.65000000000000002,
#  0.5,
#  0.84999999999999998,
#  0.62,
#  0.96999999999999997)

# %%
cancer_loss
# Out:
# 0.62

# %%
cancer_acc
# Out:
# 0.84999999999999998

# %%
import json

with open('logs_%s.json'%name, 'w') as fp:
    json.dump(cb.logs, fp)
with open('evals_%s.json'%name, 'w') as fp:
    json.dump(cb.evaluations, fp) 
with open('evaluation_%s.txt'%name, 'w') as fp:
    fp.write('%s'%(str(model.evaluate_generator(generator(filepath='data/test.tsv'),100))))

# %%
#predicted = model.predict_generator(generator(filepath='data/training.tsv'),400)

# %%
from gtts import gTTS
import os
tts = gTTS(text="The experiment is done!", lang='en-uk')
tts.save("done.mp3")
os.system("mpg321 done.mp3")
